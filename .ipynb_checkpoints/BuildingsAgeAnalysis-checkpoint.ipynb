# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
ageSource = "ConEdison/pluto_20v3.csv"
leaksSource = "ConEdison/GasHistory_2010_ReportFrequency_Monthly.csv"

# %%
buildings_df = pd.read_csv(ageSource)
leaks_df = pd.read_csv(leaksSource)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-3-30194e5b96f7> in <module>
# ----> 1 buildings_df = pd.read_csv(ageSource)
#       2 leaks_df = pd.read_csv(leaksSource)
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %%
df.head()
# Out:
#   borough  block   lot     cd  ct2010  cb2010  schooldist  council  zipcode  \
# 0      MN      1   401  101.0  317.03     1.0         NaN      1.0      NaN
# 1      BX   3328    32  207.0  431.00  3000.0        10.0     11.0  10467.0
# 2      BK   1163    37  308.0  305.00  4001.0        17.0     35.0  11238.0
# 3      QN  16174  7502  414.0  942.01  1029.0        27.0     32.0  11694.0
# 4      QN   1229    50  402.0  259.00  2001.0        30.0     26.0  11377.0
#
#   firecomp  ...        appbbl     appdate  plutomapid version sanitdistrict  \
# 0      NaN  ...           NaN         NaN           4    20v3           NaN
# 1     L039  ...           NaN         NaN           1    20v3           7.0
# 2     E219  ...           NaN         NaN           1    20v3           8.0
# 3     E268  ...  4.161740e+09  06/19/2007           1    20v3          14.0
# 4     E292  ...           NaN         NaN           1    20v3           2.0
#
# ...

# %%
df.columns
# Out:
# Index(['borough', 'block', 'lot', 'cd', 'ct2010', 'cb2010', 'schooldist',
#        'council', 'zipcode', 'firecomp', 'policeprct', 'healtharea',
#        'sanitboro', 'sanitsub', 'address', 'zonedist1', 'zonedist2',
#        'zonedist3', 'zonedist4', 'overlay1', 'overlay2', 'spdist1', 'spdist2',
#        'spdist3', 'ltdheight', 'splitzone', 'bldgclass', 'landuse',
#        'easements', 'ownertype', 'ownername', 'lotarea', 'bldgarea', 'comarea',
#        'resarea', 'officearea', 'retailarea', 'garagearea', 'strgearea',
#        'factryarea', 'otherarea', 'areasource', 'numbldgs', 'numfloors',
#        'unitsres', 'unitstotal', 'lotfront', 'lotdepth', 'bldgfront',
#        'bldgdepth', 'ext', 'proxcode', 'irrlotcode', 'lottype', 'bsmtcode',
#        'assessland', 'assesstot', 'exempttot', 'yearbuilt', 'yearalter1',
#        'yearalter2', 'histdist', 'landmark', 'builtfar', 'residfar', 'commfar',
#        'facilfar', 'borocode', 'bbl', 'condono', 'tract2010', 'xcoord',
# ...

# %%
df = df[['address', 'landuse', 'yearbuilt', 'yearalter1', 'yearalter2','firecomp', 'policeprct','borough','ct2010', 'cb2010',  'latitude', 'longitude']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 858979 entries, 0 to 858978
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   address     858514 non-null  object
#  1   landuse     856085 non-null  float64
#  2   yearbuilt   858514 non-null  float64
#  3   yearalter1  858514 non-null  float64
#  4   yearalter2  858514 non-null  float64
#  5   firecomp    856938 non-null  object
#  6   policeprct  856947 non-null  float64
#  7   borough     858979 non-null  object
#  8   ct2010      857660 non-null  float64
#  9   cb2010      857660 non-null  float64
#  10  latitude    857560 non-null  float64
#  11  longitude   857560 non-null  float64
# dtypes: float64(9), object(3)
# memory usage: 78.6+ MB

# %%
# remove all rows where the location or yearBuilt is missing
df = df[(df['latitude'].notna()) & (df['yearbuilt'].notna())]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 857095 entries, 0 to 858978
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   address     857095 non-null  object
#  1   landuse     854754 non-null  float64
#  2   yearbuilt   857095 non-null  float64
#  3   yearalter1  857095 non-null  float64
#  4   yearalter2  857095 non-null  float64
#  5   firecomp    856354 non-null  object
#  6   policeprct  856363 non-null  float64
#  7   borough     857095 non-null  object
#  8   ct2010      857071 non-null  float64
#  9   cb2010      857071 non-null  float64
#  10  latitude    857095 non-null  float64
#  11  longitude   857095 non-null  float64
# dtypes: float64(9), object(3)
# memory usage: 85.0+ MB

# %%
df.head()
# Out:
#                  address  landuse  yearbuilt  yearalter1  yearalter2 firecomp  \
# 0   JOE DIMAGGIO HIGHWAY      7.0     1949.0         0.0         0.0      NaN
# 1      ROCHAMBEAU AVENUE      7.0        0.0         0.0         0.0     L039
# 2         PROSPECT PLACE      7.0        0.0         0.0         0.0     E219
# 3  1-68 BEACH 101 STREET      2.0        0.0         0.0         0.0     E268
# 4              39 AVENUE      7.0        0.0         0.0         0.0     E292
#
#    policeprct borough  ct2010  cb2010   latitude  longitude
# 0         NaN      MN  317.03     1.0  40.714289 -74.020911
# 1        52.0      BX  431.00  3000.0  40.884132 -73.879761
# 2        77.0      BK  305.00  4001.0  40.674838 -73.957651
# 3       100.0      QN  942.01  1029.0  40.582485 -73.821345
# 4       108.0      QN  259.00  2001.0  40.746944 -73.904210

# %%
df = df[df['yearbuilt']!=0]
# remove all null rows
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 815345 entries, 7 to 858972
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   address     815345 non-null  object
#  1   landuse     815345 non-null  float64
#  2   yearbuilt   815345 non-null  float64
#  3   yearalter1  815345 non-null  float64
#  4   yearalter2  815345 non-null  float64
#  5   firecomp    815345 non-null  object
#  6   policeprct  815345 non-null  float64
#  7   borough     815345 non-null  object
#  8   ct2010      815345 non-null  float64
#  9   cb2010      815345 non-null  float64
#  10  latitude    815345 non-null  float64
#  11  longitude   815345 non-null  float64
# dtypes: float64(9), object(3)
# memory usage: 80.9+ MB

# %%
df.head()
# Out:
#                  address  landuse  yearbuilt  yearalter1  yearalter2 firecomp  \
# 7           146 2 AVENUE      4.0     1900.0      2001.0         0.0     L011
# 10   243 MORELAND STREET      1.0     2019.0         0.0         0.0     L081
# 12  454 BEACH 125 STREET      1.0     1950.0         0.0         0.0     L137
# 13  460 BEACH 125 STREET      1.0     1970.0         0.0         0.0     L137
# 14     49 EAST 95 STREET      2.0     1930.0         0.0         0.0     E283
#
#     policeprct borough  ct2010  cb2010   latitude  longitude
# 7          9.0      MN   40.00  4000.0  40.729203 -73.986784
# 10       122.0      SI  112.02  2015.0  40.573513 -74.098158
# 12       100.0      QN  934.01  1005.0  40.580536 -73.846269
# 13       100.0      QN  934.01  1005.0  40.580649 -73.846334
# 14        67.0      BK  884.00  1000.0  40.664318 -73.926114
